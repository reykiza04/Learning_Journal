# %% [markdown]
# # ML Mas danu
# Hari ini bahas terminologi ML
#
# Machine Learning !!!!!!!!!!!!!!!!!!!!!!!!
# tambahan di kelas ?
# anita antono, ilyasa

# %% [markdown]
# # What is ML?
#  > suatu bidang di dalam ilkom yang di gunakan agar komputer dpt mempelajari sesuatu tanpa di program secara eksplisit
#
#  - contoh belajar untuk membedakan spam di email (kita bisa membuat variabel yang berisikan keywoard spam)
# - cara di phase 0 adalah cara tradisional
#
# > Tradisional
#     - data,
#     - rule (program)
#
#     -> output
#
# > ML
#     - data,
#     - output
#     -> yang di hasilkan adalah rule
#
# levelnya sudah bisa baca struktur kalimat SPOK
# melihat pola dari kalimat
#
#
# intinya tanpa di program secara eksplisit
#
# atau kita akan membuat MODEL !
# rules yang di buat oleh komputer untuk memecahkan masalah
#
# Jumat akan belajar model evaluation melihat bagus atau ga bagus
#
# - Supervised
# - Unsupervised
#
# kalo menggunakan cara tradisional bukan cara yang bagus karena akan terlalu panjang
#
#
# - jadi kita harus belajar tentang variasi data agar bisa menentukan rules
#
# > Supervised learning (dengan terget)
#     - kita punya data dan output
#         - ada label dan target
#         - data / feature
#     - di pecah jadi 2
#         -classification
#             -memprediksi kelas (spam ,non spam)
#         -regresion
#             - memprediksi number (angka jutaan milyaraan)
#
#
#     - algoritmanya
#         -banyakkkkkk liat di kode,id
#
#
# > Classification
#     - meenentukan target label datta dulu
#
#     - binari classification (total kelas ada2, male female, spam no spam, yes/no)
#     - multiclass classification (mode than 2, tapi output harus 1)
#         - detec hewan dari gambar
#         - face recognition
#         - brand detection (appel,lg,samsung)
#
#     - multi label ( peluasan dari multi class),
#         - klasifikasi berita (politik ekonomi)
#         - film ( horor komedi)
#         - musik (genere)
#
#     - element pembuat model aadalah DATA, untuk menemukan tujuanya
#
#
# > Unsupervised (tanpa target)
#     -rekomendasi artikel, (model rekomendation)
#         - di gruop cluster dari pengguna baru di berikan rekomendasi jadi bukan per user agar cut time
#
#     - intinya clustering kita tidak butuh target
#
#
# > SEMI SUPERVISED (gabungan)
#     - semakin banyak data semakin bnyk model belajar
#     misal dari data akan di kelompokan dan akan di labelkan karena kemiripan mereka yang di petakan kedalam grafik
#
#         jadi. un supervised dulu (cluster), baru di supervised - kasus yan gbiasanya terjadi
#
#
#
#
# > Reinforcement learning
#     Pembuatan AI berdasarkan data yang sudah ada
#     kita berikan projectary optimal, jika dia mendekati maka akan di berikan reward(angka) dan punishment(angka)
#     jadi yang di berikan adalah ruang keadaan ( mana yang memberikan hasil terbaik akan di berikan lebel baik), terus di optimalkan
#
#     contoh penggunaan level pada game
#
#     di pelajari SUPERSIVED DAN UNSUPERVISED (reinforcement belum bisa sendiri nanti kalu uda jago hmm)

# %%
# ML

# %% [markdown]
# X dan y  beswar kecil uda jadi rule tak tertulis DS
# dalam kasus machine learning
# ada yang namanya training machine
#
# # ini supervised
#
# X_train (buku cpns)
# y_train (kunci jawaban)
# ni bedua di pelajari sama mesin
#
#
#
# ------------------------------------
# masuk ke testing
# X_test
# akan menghasilkan
# y_pre
# --------------------------------------
#
# koreksi
# y_test
# y_pred
#
#
# ada train sheet
# ada test sheet
# di bagi 70% train
# 30% test
#
# pemotonganya si bebas, semakin banyak data di traininng makin bagus, tapi hasil akhirnya tergantung
# 60-80 train
# sisanya testing
#
# model ini updatenya bulanan ( training model dan datanya)
#
# tapi datanya harus di split dengan acak agar hasil maksimal trainingnya (agar ga berpola saat training)
#
# # regresi
#     eror 0%
#
#
#
#
#     ------------------------------------------
#
#     sklearn aka di gunakan sekali saat di phase 1 ini
#
#     di ML model harus memproses suatu data yang bentuknya numerik
#     harus di rubah gabisa proses di STR harus di konvert
#
#
#     spliting data TIDAK BOLEH BERURUTAN !!!!!!!!!! nanti bias
